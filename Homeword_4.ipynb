# %%
import math 
from scipy import stats

# %% [markdown]
# #### Задача 1

# %% [markdown]
# О непрерывной равномерно распределенной случайной величине `B` известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины `B` и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %%
d = 0.2
a = 0.5
b = a + math.sqrt(d * 12)
b
# Out:
# 2.049193338482967

# %%
m = (a + b) / 2
m
# Out:
# 1.2745966692414834

# %% [markdown]
# #### Задача 2

# %% [markdown]
# Рост взрослого населения города `X` имеет нормальное распределение, причем, средний рост равен 174 см, а среднее квадратическое отклонение равно 8 см. посчитайте, какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# 1. больше 182 см?
# 2. больше 190 см?
# 3. от 166 см до 190 см?
# 4. от 166 см до 182 см?
# 5. от 158 см до 190 см?
# 6. не выше 150 см или не ниже 190 см?
# 7. не выше 150 см или не ниже 198 см?
# 8. ниже 166 см?
#
# Задачу можно решить двумя способами: без использования сторонних библиотек (`numpy`, `scipy`, `pandas` и пр.), а затем проверить себя с помощью встроенных функций

# %%
loc = 174
scale = 8

# %%
ans_1 = 1 - stats.norm.cdf(182, loc, scale)
ans_1
# Out:
# 0.15865525393145707

# %%
ans_2 = 1 - stats.norm.cdf(190, loc, scale)
ans_2
# Out:
# 0.02275013194817921

# %%
ans_3_1 = stats.norm.cdf(190, loc, scale)
ans_3_2 = stats.norm.cdf(166, loc, scale)
ans_3 = ans_3_1 - ans_3_2
ans_3_1, ans_3_2, ans_3
# Out:
# (0.9772498680518208, 0.15865525393145707, 0.8185946141203637)

# %%
ans_4_1 = stats.norm.cdf(182, loc, scale)
ans_4_2 = stats.norm.cdf(166, loc, scale)
ans_4 = ans_4_1 - ans_4_2
ans_4_1, ans_4_2, ans_4
# Out:
# (0.8413447460685429, 0.15865525393145707, 0.6826894921370859)

# %%
ans_5_1 = stats.norm.cdf(190, loc, scale)
ans_5_2 = stats.norm.cdf(158, loc, scale)
ans_5 = ans_5_1 - ans_5_2
ans_5_1, ans_5_2, ans_5
# Out:
# (0.9772498680518208, 0.022750131948179195, 0.9544997361036416)

# %%
ans_6_1 = stats.norm.cdf(150, loc, scale)
ans_6_2 = 1 - stats.norm.cdf(190, loc, scale)
ans_6 = ans_6_1 + ans_6_2
ans_6_1, ans_6_2, ans_6
# Out:
# (0.0013498980316300933, 0.02275013194817921, 0.0241000299798093)

# %%
ans_7_1 = stats.norm.cdf(150, loc, scale)
ans_7_2 = 1 - stats.norm.cdf(198, loc, scale)
ans_7 = ans_7_1 + ans_7_2
ans_7_1, ans_7_2, ans_7
# Out:
# (0.0013498980316300933, 0.0013498980316301035, 0.0026997960632601965)

# %%
ans_7 = stats.norm.cdf(166, loc, scale)
ans_7
# Out:
# 0.15865525393145707

# %% [markdown]
# #### Задача 3

# %% [markdown]
# Коробки с шоколадом упаковываются автоматически. Их средняя масса равна 1.06 кг. Известно, что 5% коробок имеют массу, меньшую 1 кг. Найдите: а) среднее квадратическое отклонение массы коробки, б) процент коробок, имеющих массу больше 1.1 кг.
#
# _Подсказка_. 1. Можно считать, что распределение массы коробки нормальное. 2. Найдите такое значение `scale`, для которого значение `cdf(x=1, loc=1.06, scale=scale)` близко к 0.05. Точности 0.0001 будет достаточно.

# %%
loc = 1.06

# %%
stats.norm.cdf(1, loc, 0.0364774)
# Out:
# 0.04999995389034858

# %%
scale = 0.0364774

# %%
stats.norm.cdf(1.1, loc, scale)
# Out:
# 0.8635851611354344
