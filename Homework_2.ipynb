# %% [markdown]
# ## Homework 2

# %%
import numpy as np

# %%
def arrangements(n, k):
    return np.math.factorial(n) // np.math.factorial(n - k)

# %%
def permutations(n):
    return np.math.factorial(n)

# %%
def combinations(n, k):
    return np.math.factorial(n) // (np.math.factorial(k) * np.math.factorial(n - k))

# %%
def probability_of_success(p, n, k):
    C_kn = combinations(n, k)
    return C_kn * (p**k) * (1 - p)**(n - k)

# %%
def poisson_proba(k, lambda_):  
    return (lambda_ ** k) * (np.exp(-lambda_)) / np.math.factorial(k)

# %% [markdown]
# #### Задача 1

# %% [markdown]
# Контрольная работа состоит из пяти вопросов. На каждый вопрос приведено четыре варианта ответа, один из которых правильный. Составьте закон распределения числа правильных ответов при простом угадывании. Найдите M(X), D(X).

# %%
n = 5
p = 0.25
x_answers = np.array([0, 1, 2, 3, 4, 5])
x_probabilities = np.empty(0)

# %%
for i in x_answers:
   x_probabilities = np.append(x_probabilities, probability_of_success(p, n, i))
x_probabilities
# Out:
# array([0.23730469, 0.39550781, 0.26367188, 0.08789062, 0.01464844,
#        0.00097656])

# %%
M_x = n * p
M_x
# Out:
# 1.25

# %%
D_x = n * p * (1 - p)
D_x
# Out:
# 0.9375

# %% [markdown]
# #### Задача 2

# %% [markdown]
# Вероятность попадания в цель при одном выстреле равна 0.01. Какова вероятность того, что число попаданий при 200 выстрелах будет не менее 5 и не более 10?

# %%
lambda_ = 200 * 0.01

# %%
sum(poisson_proba(i, lambda_) for i in range(5,11))
# Out:
# 0.052644709119342686

# %% [markdown]
# #### Задача 3

# %% [markdown]
# В условиях предыдущей задачи сколько выстрелов нужно сделать чтобы быть уверенным с вероятностью 0.9, что хотя бы 10 раз будет совершено попадание?
#
# Подсказка. Как посчитать P(X >= k) для величины X, имеющей распределение Пуассона? Здесь предстоит немножко покодить.

# %%
n = 1421
lambda_ = 0.01 * n
b = 1 - sum(poisson_proba(i, lambda_) for i in range(10))
  
print(n, b)
# Out:
# 1421 0.9001760722984115
